# %% [markdown]
# ## Scaling the training process with compute clusters

# %%
from azureml.core import Workspace, Experiment
from azureml.core import ScriptRunConfig

ws = Workspace.from_config()
target = ws.compute_targets['akt-cluster']

script = ScriptRunConfig(
    source_directory='greeter-job',
    script='greeter.py',
    compute_target=target,
    arguments=['--greet-name', 'Henry']
)

exp = Experiment(ws, 'greet-run')
run = exp.submit(script)
print(run.get_portal_url())
run.wait_for_completion(show_output=True)
# Out:
# https://ml.azure.com/runs/greet-run_1650543543_439eb114?wsid=/subscriptions/a8b508b6-da16-4c45-84f5-cac5c9f57513/resourcegroups/azure-mlops/workspaces/prod-dev-ml-ws&tid=e648628f-f65c-40cc-8a28-c601daf26a89
# RunId: greet-run_1650543543_439eb114
# Web View: https://ml.azure.com/runs/greet-run_1650543543_439eb114?wsid=/subscriptions/a8b508b6-da16-4c45-84f5-cac5c9f57513/resourcegroups/azure-mlops/workspaces/prod-dev-ml-ws&tid=e648628f-f65c-40cc-8a28-c601daf26a89
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2022/04/21 12:19:10 Downloading source code...
# 2022/04/21 12:19:11 Finished downloading source code
# 2022/04/21 12:19:11 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/04/21 12:19:11 Successfully set up Docker network: acb_default_network
# 2022/04/21 12:19:11 Setting up Docker configuration...
# 2022/04/21 12:19:12 Successfully set up Docker configuration
# 2022/04/21 12:19:12 Logging in to registry: proddevmlwscontainerreg.azurecr.io
# 2022/04/21 12:19:13 Successfully logged into proddevmlwscontainerreg.azurecr.io
# 2022/04/21 12:19:13 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/04/21 12:19:13 Scanning for dependencies...
# 2022/04/21 12:19:13 Successfully scanned dependencies
# 2022/04/21 12:19:13 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220314.v1@sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220314.v1@sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# cf06a7c31611: Pulling fs layer
# 0159d711301b: Pulling fs layer
# 8b88847355b9: Pulling fs layer
# 509bd2a1e221: Pulling fs layer
# cf0f998fa79d: Pulling fs layer
# 67863f775d4e: Pulling fs layer
# 99cfd53d22e8: Pulling fs layer
# 37392413e856: Pulling fs layer
# b03ca6cd8f42: Pulling fs layer
# 509bd2a1e221: Waiting
# cf0f998fa79d: Waiting
# 67863f775d4e: Waiting
# 99cfd53d22e8: Waiting
# 37392413e856: Waiting
# b03ca6cd8f42: Waiting
# cf06a7c31611: Verifying Checksum
# cf06a7c31611: Download complete
# 8b88847355b9: Verifying Checksum
# 8b88847355b9: Download complete
# 509bd2a1e221: Download complete
# 67863f775d4e: Verifying Checksum
# 67863f775d4e: Download complete
# 99cfd53d22e8: Verifying Checksum
# 99cfd53d22e8: Download complete
# cf0f998fa79d: Verifying Checksum
# cf0f998fa79d: Download complete
# 0159d711301b: Verifying Checksum
# 0159d711301b: Download complete
# b03ca6cd8f42: Verifying Checksum
# b03ca6cd8f42: Download complete
# 37392413e856: Verifying Checksum
# 37392413e856: Download complete
# cf06a7c31611: Pull complete
# 0159d711301b: Pull complete
# 8b88847355b9: Pull complete
# 509bd2a1e221: Pull complete
# cf0f998fa79d: Pull complete
# 67863f775d4e: Pull complete
# 99cfd53d22e8: Pull complete
# 37392413e856: Pull complete
# b03ca6cd8f42: Pull complete
# Digest: sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220314.v1@sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980
#  ---> 849454c66968
# Step 2/21 : USER root
#  ---> Running in c2cd9fc537fb
# Removing intermediate container c2cd9fc537fb
#  ---> cb03bdf64c29
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in 30930aacc6c0
# Removing intermediate container 30930aacc6c0
#  ---> c2b15ff8c9a2
# Step 4/21 : WORKDIR /
#  ---> Running in a8a4a4ab6681
# Removing intermediate container a8a4a4ab6681
#  ---> f04ef73cd107
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> b908cbe96d15
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in fc235dbf70ad
# Removing intermediate container fc235dbf70ad
#  ---> 458c171622ca
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> b131ae3df1ce
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in c917242a14bc
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #2         |  13%
# python-3.6.2         | 27.0 MB   | ##5        |  26%
# python-3.6.2         | 27.0 MB   | #####2     |  53%
# python-3.6.2         | 27.0 MB   | #######4   |  75%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #########9 |  99%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.whl13igg.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.40.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-inference-server-http~=0.4.1
#   Downloading azureml_inference_server_http-0.4.13-py3-none-any.whl (39 kB)
# Collecting azureml-core~=1.40.0
#   Downloading azureml_core-1.40.0.post2-py3-none-any.whl (2.7 MB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.40.0
#   Downloading azureml_dataset_runtime-1.40.0-py3-none-any.whl (3.5 kB)
# Collecting opencensus-ext-azure~=1.1.0
#   Downloading opencensus_ext_azure-1.1.4-py2.py3-none-any.whl (40 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting click<8.0,>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting gunicorn==20.1.0; platform_system != "Windows"
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting Jinja2<3.1,>=2.10.1
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting itsdangerous<2.0,>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Werkzeug<2.0,>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.2-py3-none-any.whl (15 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-storage<20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-19.1.0-py3-none-any.whl (1.8 MB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting argcomplete<2.0
#   Downloading argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-containerregistry<9.0.0,>=8.2.0
#   Downloading azure_mgmt_containerregistry-8.2.0-py2.py3-none-any.whl (928 kB)
# Collecting packaging<22.0,>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.3.0-py2.py3-none-any.whl (412 kB)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting azure-mgmt-resource<21.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-20.1.0-py3-none-any.whl (2.3 MB)
# Collecting pytz
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.17.0-py2.py3-none-any.whl (79 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting knack~=0.9.0
#   Downloading knack-0.9.0-py3-none-any.whl (59 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting urllib3<=1.26.7,>=1.23
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting pyopenssl<22.0.0
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting msal-extensions<0.4,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.10.3-py2.py3-none-any.whl (211 kB)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.1.0-py2.py3-none-any.whl (38 kB)
# Collecting azure-core<1.22
#   Downloading azure_core-1.21.1-py2.py3-none-any.whl (178 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting pkginfo
#   Downloading pkginfo-1.8.2-py2.py3-none-any.whl (26 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0
#   Downloading cryptography-36.0.2-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
# Collecting numpy!=1.19.3; sys_platform == "linux"
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Collecting azureml-dataprep<3.1.0a,>=3.0.0a
#   Downloading azureml_dataprep-3.0.2-py3-none-any.whl (38.6 MB)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.9.0-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (279 kB)
# Collecting azure-identity<2.0.0,>=1.5.0
#   Downloading azure_identity-1.9.0-py3-none-any.whl (134 kB)
# Collecting opencensus<1.0.0,>=0.8.0
#   Downloading opencensus-0.9.0-py2.py3-none-any.whl (128 kB)
# Requirement already satisfied, skipping upgrade: setuptools>=3.0 in /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/lib/python3.6/site-packages (from gunicorn==20.1.0; platform_system != "Windows"->azureml-inference-server-http~=0.4.1->azureml-defaults->-r /azureml-environment-setup/condaenv.whl13igg.requirements.txt (line 1)) (50.3.0.post20201006)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux2010_x86_64.whl (30 kB)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.3.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting importlib-metadata<5,>=0.23; python_version == "3.6"
#   Downloading importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.7-py3-none-any.whl (98 kB)
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting pygments
#   Downloading Pygments-2.11.2-py3-none-any.whl (1.1 MB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting portalocker<3,>=1.0; python_version >= "3.5" and platform_system != "Windows"
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (61 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/lib/python3.6/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.40.0->azureml-defaults->-r /azureml-environment-setup/condaenv.whl13igg.requirements.txt (line 1)) (2020.6.20)
# Collecting idna<4,>=2.5; python_version >= "3"
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting PySocks!=1.5.7,>=1.5.6; extra == "socks"
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.1-py3-none-any.whl (54 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (405 kB)
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.23-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting azureml-dataprep-rslex~=2.4.0dev0
#   Downloading azureml_dataprep_rslex-2.4.3-cp36-cp36m-manylinux1_x86_64.whl (14.5 MB)
# Collecting opencensus-context>=0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"
#   Downloading google_api_core-2.7.2-py3-none-any.whl (114 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Collecting contextvars; python_version >= "3.6" and python_version < "3.7"
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.6.5-py2.py3-none-any.whl (156 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.19.4-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting googleapis-common-protos<2.0dev,>=1.52.0
#   Downloading googleapis_common_protos-1.56.0-py2.py3-none-any.whl (241 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.17-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (115 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=977b70c36fb049039b350c9172c37a3e0fdcbfdc9f32a46745fdf6172c4b4587
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=f7027cac5799552b6cfd7043f6108cb06040a6bc1d23fc559cec4865aa199a2a
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69871 sha256=4f23b98f8128a40071f9bfae94746e7aa6d7d1bbc501e799ff761ed11c98dd31
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7665 sha256=a80724597652511811c849aa665a9ec8d4853a6c9bcc31e6593a1b619a440cef
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy wrapt contextvars
# Installing collected packages: psutil, charset-normalizer, urllib3, idna, PySocks, requests, six, azure-core, portalocker, PyJWT, pycparser, cffi, cryptography, msal, msal-extensions, azure-identity, typing-extensions, immutables, contextvars, opencensus-context, pyasn1, pyasn1-modules, cachetools, rsa, google-auth, protobuf, googleapis-common-protos, google-api-core, opencensus, opencensus-ext-azure, click, Werkzeug, MarkupSafe, Jinja2, itsdangerous, flask, applicationinsights, gunicorn, pytz, python-dateutil, wrapt, inference-schema, azureml-inference-server-http, oauthlib, requests-oauthlib, isodate, msrest, azure-common, adal, msrestazure, azure-graphrbac, jeepney, SecretStorage, backports.weakref, backports.tempfile, azure-mgmt-core, azure-mgmt-storage, contextlib2, pyopenssl, ndg-httpsclient, zipp, importlib-metadata, argcomplete, azure-mgmt-containerregistry, pyparsing, packaging, azure-mgmt-keyvault, humanfriendly, azure-mgmt-resource, pygments, jmespath, tabulate, pyyaml, knack, bcrypt, pynacl, paramiko, jsonpickle, websocket-client, docker, pathspec, pkginfo, azure-mgmt-authorization, azureml-core, configparser, json-logging-py, numpy, cloudpickle, azureml-dataprep-native, distro, dotnetcore2, azureml-dataprep-rslex, azureml-dataprep, pyarrow, fusepy, azureml-dataset-runtime, azureml-defaults
# Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 PyJWT-2.3.0 PySocks-1.7.1 SecretStorage-3.3.2 Werkzeug-1.0.1 adal-1.2.7 applicationinsights-0.11.10 argcomplete-1.12.3 azure-common-1.1.28 azure-core-1.21.1 azure-graphrbac-0.61.1 azure-identity-1.9.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.2.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.3.0 azure-mgmt-resource-20.1.0 azure-mgmt-storage-19.1.0 azureml-core-1.40.0.post2 azureml-dataprep-3.0.2 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.4.3 azureml-dataset-runtime-1.40.0 azureml-defaults-1.40.0 azureml-inference-server-http-0.4.13 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.2.0 cachetools-4.2.4 cffi-1.15.0 charset-normalizer-2.0.12 click-7.1.2 cloudpickle-2.0.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-36.0.2 distro-1.7.0 docker-5.0.3 dotnetcore2-2.1.23 flask-1.0.3 fusepy-3.0.1 google-api-core-2.7.2 google-auth-2.6.5 googleapis-common-protos-1.56.0 gunicorn-20.1.0 humanfriendly-10.0 idna-3.3 immutables-0.17 importlib-metadata-4.8.3 inference-schema-1.3.0 isodate-0.6.1 itsdangerous-1.1.0 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.1.0 knack-0.9.0 msal-1.17.0 msal-extensions-0.3.1 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.19.5 oauthlib-3.2.0 opencensus-0.9.0 opencensus-context-0.1.2 opencensus-ext-azure-1.1.4 packaging-21.3 paramiko-2.10.3 pathspec-0.9.0 pkginfo-1.8.2 portalocker-2.4.0 protobuf-3.19.4 psutil-5.9.0 pyarrow-3.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.21 pygments-2.11.2 pynacl-1.5.0 pyopenssl-21.0.0 pyparsing-3.0.7 python-dateutil-2.8.2 pytz-2022.1 pyyaml-6.0 requests-2.27.1 requests-oauthlib-1.3.1 rsa-4.8 six-1.16.0 tabulate-0.8.9 typing-extensions-4.1.1 urllib3-1.26.7 websocket-client-1.3.1 wrapt-1.12.1 zipp-3.6.0
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container c917242a14bc
#  ---> b66cf13d15c4
# Step 9/21 : ENV PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin:$PATH
#  ---> Running in 48bebad6f53f
# Removing intermediate container 48bebad6f53f
#  ---> 58eccd60d707
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 14e75fd29dd2
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in dd41fd42667c
# Copying environment context
# Removing intermediate container dd41fd42667c
#  ---> 5b39673aff20
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 24ac1aaa4a42
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad
#  ---> Running in a77d843f4580
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container a77d843f4580
#  ---> fef827bad5d2
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad
#  ---> Running in a57c6488ac76
# Removing intermediate container a57c6488ac76
#  ---> 3a763626e3ac
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/lib:$LD_LIBRARY_PATH
#  ---> Running in 680a00027ec5
# Removing intermediate container 680a00027ec5
#  ---> 52bc05ed7f68
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_da3e97fcb51801118b8e80207f3e01ad CONDA_PREFIX=/azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad
#  ---> Running in 77d960b17ade
# Removing intermediate container 77d960b17ade
#  ---> 9452769a4aa9
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 0e24494edc58
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 60a041532bf0
# Removing intermediate container 60a041532bf0
#  ---> 17f258491495
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in 65f6defc3312
# Removing intermediate container 65f6defc3312
#  ---> 1ccabf70da3a
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 0b54cc68b361
# Removing intermediate container 0b54cc68b361
#  ---> 5e3e9372515e
# Step 21/21 : CMD ["bash"]
#  ---> Running in c930695486e4
# Removing intermediate container c930695486e4
#  ---> c472020e27cd
# Successfully built c472020e27cd
# Successfully tagged proddevmlwscontainerreg.azurecr.io/azureml/azureml_bcc7c8d4f810d35543e812eb7500a442:latest
# Successfully tagged proddevmlwscontainerreg.azurecr.io/azureml/azureml_bcc7c8d4f810d35543e812eb7500a442:1
# 2022/04/21 12:21:37 Successfully executed container: acb_step_0
# 2022/04/21 12:21:37 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/04/21 12:21:37 Pushing image: proddevmlwscontainerreg.azurecr.io/azureml/azureml_bcc7c8d4f810d35543e812eb7500a442:1, attempt 1
# The push refers to repository [proddevmlwscontainerreg.azurecr.io/azureml/azureml_bcc7c8d4f810d35543e812eb7500a442]
# 8ac79c855418: Preparing
# 77efd786813e: Preparing
# 2e26066bef52: Preparing
# bad203fb89c6: Preparing
# b7f4c3ba4020: Preparing
# 15bb19232365: Preparing
# 323f439a632f: Preparing
# cdc89957ab4e: Preparing
# c75b849c8f9f: Preparing
# 4a9c76619927: Preparing
# 152ab1cf0506: Preparing
# 2a8c27ecc2d4: Preparing
# c289ce712c06: Preparing
# ed535c57edb5: Preparing
# d402679c3e9d: Preparing
# 02b786e5916e: Preparing
# 04c54c9cadfd: Preparing
# e83750761fa5: Preparing
# a4e25480be6b: Preparing
# 152ab1cf0506: Waiting
# 2a8c27ecc2d4: Waiting
# c289ce712c06: Waiting
# ed535c57edb5: Waiting
# d402679c3e9d: Waiting
# 02b786e5916e: Waiting
# 04c54c9cadfd: Waiting
# e83750761fa5: Waiting
# a4e25480be6b: Waiting
# 323f439a632f: Waiting
# cdc89957ab4e: Waiting
# c75b849c8f9f: Waiting
# 4a9c76619927: Waiting
# 15bb19232365: Waiting
# bad203fb89c6: Pushed
# 8ac79c855418: Pushed
# 2e26066bef52: Pushed
# b7f4c3ba4020: Pushed
# 323f439a632f: Pushed
# 77efd786813e: Pushed
# cdc89957ab4e: Pushed
# c75b849c8f9f: Pushed
# 2a8c27ecc2d4: Pushed
# 152ab1cf0506: Pushed
# 4a9c76619927: Pushed
# c289ce712c06: Pushed
# 02b786e5916e: Pushed
# ed535c57edb5: Pushed
#
# 04c54c9cadfd: Pushed
#
# d402679c3e9d: Pushed
# a4e25480be6b: Pushed
# e83750761fa5: Pushed
# 15bb19232365: Pushed
# 1: digest: sha256:5680cf8d92d92fbee051b00135c0db780333bf84ce6c65081a4b2f53dc7d43d7 size: 4306
# 2022/04/21 12:22:33 Successfully pushed image: proddevmlwscontainerreg.azurecr.io/azureml/azureml_bcc7c8d4f810d35543e812eb7500a442:1
# 2022/04/21 12:22:33 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/04/21 12:22:33 Pushing image: proddevmlwscontainerreg.azurecr.io/azureml/azureml_bcc7c8d4f810d35543e812eb7500a442:latest, attempt 1
# The push refers to repository [proddevmlwscontainerreg.azurecr.io/azureml/azureml_bcc7c8d4f810d35543e812eb7500a442]
# 8ac79c855418: Preparing
# 77efd786813e: Preparing
# 2e26066bef52: Preparing
# bad203fb89c6: Preparing
# b7f4c3ba4020: Preparing
# 15bb19232365: Preparing
# 323f439a632f: Preparing
# cdc89957ab4e: Preparing
# c75b849c8f9f: Preparing
# 4a9c76619927: Preparing
# 152ab1cf0506: Preparing
# 2a8c27ecc2d4: Preparing
# c289ce712c06: Preparing
# ed535c57edb5: Preparing
# d402679c3e9d: Preparing
# 02b786e5916e: Preparing
# 04c54c9cadfd: Preparing
# e83750761fa5: Preparing
# a4e25480be6b: Preparing
# 15bb19232365: Waiting
# 323f439a632f: Waiting
# cdc89957ab4e: Waiting
# ed535c57edb5: Waiting
# d402679c3e9d: Waiting
# c75b849c8f9f: Waiting
# 02b786e5916e: Waiting
# 04c54c9cadfd: Waiting
# 4a9c76619927: Waiting
# e83750761fa5: Waiting
# 152ab1cf0506: Waiting
# 2a8c27ecc2d4: Waiting
# c289ce712c06: Waiting
# a4e25480be6b: Waiting
# 8ac79c855418: Layer already exists
# 2e26066bef52: Layer already exists
# bad203fb89c6: Layer already exists
# 77efd786813e: Layer already exists
# b7f4c3ba4020: Layer already exists
# 323f439a632f: Layer already exists
# cdc89957ab4e: Layer already exists
# c75b849c8f9f: Layer already exists
# 15bb19232365: Layer already exists
# 152ab1cf0506: Layer already exists
# 2a8c27ecc2d4: Layer already exists
# c289ce712c06: Layer already exists
# ed535c57edb5: Layer already exists
# 02b786e5916e: Layer already exists
# d402679c3e9d: Layer already exists
# e83750761fa5: Layer already exists
# 04c54c9cadfd: Layer already exists
# a4e25480be6b: Layer already exists
# 4a9c76619927: Layer already exists
# latest: digest: sha256:5680cf8d92d92fbee051b00135c0db780333bf84ce6c65081a4b2f53dc7d43d7 size: 4306
# 2022/04/21 12:22:35 Successfully pushed image: proddevmlwscontainerreg.azurecr.io/azureml/azureml_bcc7c8d4f810d35543e812eb7500a442:latest
# 2022/04/21 12:22:35 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 144.155217)
# 2022/04/21 12:22:35 Populating digests for step ID: acb_step_0...
# 2022/04/21 12:22:36 Successfully populated digests for step ID: acb_step_0
# 2022/04/21 12:22:36 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 56.656812)
# 2022/04/21 12:22:36 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.618046)
# 2022/04/21 12:22:36 The following dependencies were found:
# 2022/04/21 12:22:36
# - image:
#     registry: proddevmlwscontainerreg.azurecr.io
#     repository: azureml/azureml_bcc7c8d4f810d35543e812eb7500a442
#     tag: latest
#     digest: sha256:5680cf8d92d92fbee051b00135c0db780333bf84ce6c65081a4b2f53dc7d43d7
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20220314.v1
#     digest: sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980
#   git: {}
# - image:
#     registry: proddevmlwscontainerreg.azurecr.io
#     repository: azureml/azureml_bcc7c8d4f810d35543e812eb7500a442
#     tag: "1"
#     digest: sha256:5680cf8d92d92fbee051b00135c0db780333bf84ce6c65081a4b2f53dc7d43d7
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20220314.v1
#     digest: sha256:7ee68e54cd31cdc4678458ae4a451ed0769828bf439bca5a736777397de4f980
#   git: {}
#
#
# Run ID: ca1 was successful after 3m27s
#
# Execution Summary
# =================
# RunId: greet-run_1650543543_439eb114
# Web View: https://ml.azure.com/runs/greet-run_1650543543_439eb114?wsid=/subscriptions/a8b508b6-da16-4c45-84f5-cac5c9f57513/resourcegroups/azure-mlops/workspaces/prod-dev-ml-ws&tid=e648628f-f65c-40cc-8a28-c601daf26a89
# {'runId': 'greet-run_1650543543_439eb114',
#  'target': 'akt-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2022-04-21T12:22:48.995024Z',
#  'endTimeUtc': '2022-04-21T12:23:31.872237Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlctrain',
#   'ContentSnapshotId': '1c05325e-0da4-4dd2-a358-ba3796e057cc',
#   'azureml.git.repository_uri': 'https://github.com/Aniketthani/Azure-Remote-Script-Execution-on-Clusters.git',
#   'mlflow.source.git.repoURL': 'https://github.com/Aniketthani/Azure-Remote-Script-Execution-on-Clusters.git',
#   'azureml.git.branch': 'main',
#   'mlflow.source.git.branch': 'main',
#   'azureml.git.commit': '6a9e584a6a9f57f3a693b331ee5df39f4387bfa2',
#   'mlflow.source.git.commit': '6a9e584a6a9f57f3a693b331ee5df39f4387bfa2',
#   'azureml.git.dirty': 'False',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'greeter.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--greet-name', 'Henry'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'akt-cluster',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'Experiment greet-run Environment',
#    'version': 'Autosave_2022-04-21T12:19:06Z_e9384b61',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'name': 'project_environment',
#      'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}],
#      'channels': ['anaconda', 'conda-forge']},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220314.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'sshPublicKeys': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.greet-run_1650543543_439eb114/azureml-logs/20_image_build_log.txt?sv=2019-07-07&sr=b&sig=9l0H4lyW4KNLaWf308DBPVahpFT7cYDXgARg9ye2KMU%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T12%3A14%3A31Z&se=2022-04-21T20%3A24%3A31Z&sp=r',
#   'user_logs/std_log.txt': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.greet-run_1650543543_439eb114/user_logs/std_log.txt?sv=2019-07-07&sr=b&sig=QfgiobrhYSbrwy1yaNBCqItNOEgWvWM%2F%2FLfTHWA8lAM%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T12%3A14%3A31Z&se=2022-04-21T20%3A24%3A31Z&sp=r',
#   'system_logs/cs_capability/cs-capability.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.greet-run_1650543543_439eb114/system_logs/cs_capability/cs-capability.log?sv=2019-07-07&sr=b&sig=7XSPGhDp7HmxKELhen4XCmGw9%2BjA5XmoJVJ%2F3nK4qSY%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T12%3A14%3A32Z&se=2022-04-21T20%3A24%3A32Z&sp=r',
#   'system_logs/hosttools_capability/hosttools-capability.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.greet-run_1650543543_439eb114/system_logs/hosttools_capability/hosttools-capability.log?sv=2019-07-07&sr=b&sig=BCBKupBmYhQTMu87enkB8RmYesM4LWarOvSpJ72fT%2Bs%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T12%3A14%3A32Z&se=2022-04-21T20%3A24%3A32Z&sp=r',
#   'system_logs/lifecycler/execution-wrapper.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.greet-run_1650543543_439eb114/system_logs/lifecycler/execution-wrapper.log?sv=2019-07-07&sr=b&sig=M2U3A8VmRRoDTUsGqi2hy8sBnAPyOCFRpwh5uKQkAfQ%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T12%3A14%3A32Z&se=2022-04-21T20%3A24%3A32Z&sp=r',
#   'system_logs/lifecycler/lifecycler.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.greet-run_1650543543_439eb114/system_logs/lifecycler/lifecycler.log?sv=2019-07-07&sr=b&sig=hZvBY59oL28ooR8Kh93RhVi9%2FCGWMbdZ%2F5DYU6Fu%2F4s%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T12%3A14%3A32Z&se=2022-04-21T20%3A24%3A32Z&sp=r',
#   'system_logs/lifecycler/vm-bootstrapper.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.greet-run_1650543543_439eb114/system_logs/lifecycler/vm-bootstrapper.log?sv=2019-07-07&sr=b&sig=t3Zup%2Bc1jKrZwSj4%2BrqfKWy71GkSFgRpnuMcoqaNwNA%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T12%3A14%3A32Z&se=2022-04-21T20%3A24%3A32Z&sp=r'},
#  'submittedBy': 'Aniket Thani'}

# %% [markdown]
# ### Exploring the outputs and logs of a run

# %%
from azureml.widgets import RunDetails

run = exp.submit(script)
RunDetails(run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %%
run.get_details_with_logs()
# Out:
# {'runId': 'greet-run_1650543902_1f9b0721',
#  'target': 'akt-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2022-04-21T12:25:11.350619Z',
#  'endTimeUtc': '2022-04-21T12:25:22.378989Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlctrain',
#   'ContentSnapshotId': '1c05325e-0da4-4dd2-a358-ba3796e057cc',
#   'azureml.git.repository_uri': 'https://github.com/Aniketthani/Azure-Remote-Script-Execution-on-Clusters.git',
#   'mlflow.source.git.repoURL': 'https://github.com/Aniketthani/Azure-Remote-Script-Execution-on-Clusters.git',
#   'azureml.git.branch': 'main',
#   'mlflow.source.git.branch': 'main',
#   'azureml.git.commit': '6a9e584a6a9f57f3a693b331ee5df39f4387bfa2',
#   'mlflow.source.git.commit': '6a9e584a6a9f57f3a693b331ee5df39f4387bfa2',
#   'azureml.git.dirty': 'False',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'greeter.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--greet-name', 'Henry'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'akt-cluster',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'Experiment greet-run Environment',
#    'version': 'Autosave_2022-04-21T12:19:06Z_e9384b61',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'name': 'project_environment',
#      'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}],
#      'channels': ['anaconda', 'conda-forge']},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220314.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'sshPublicKeys': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'user_logs/std_log.txt': 'Hello Henry!\nCleaning up all outstanding Run operations, waiting 300.0 seconds\n0 items cleaning up...\nCleanup took 1.1920928955078125e-06 seconds\n',
#   'system_logs/cs_capability/cs-capability.log': 'INFO 2022-04-21 12:25:11,940 initializer.py:57 [1] - job_telemetry_init {\'artifact_type\': \'installed\', \'ci_number\': \'20220418.5\', \'ci_name\': \'CommonRuntime-prod-build\', \'build_time\': \'2022-04-19 05:16:44.989920\', \'subscription_id\': \'a8b508b6-da16-4c45-84f5-cac5c9f57513\', \'resource_group\': \'azure-mlops\', \'workspace_name\': \'prod-dev-ml-ws\', \'workspace_location\': \'eastus\', \'experiment_name\': \'greet-run\', \'node_rank\': \'0\', \'node_id\': \'a5beda79-6c6a-4baf-8bc0-f0fb8a90c8f1\', \'run_id\': \'greet-run_1650543902_1f9b0721\', \'correlation_id\': \'greet-run_1650543902_1f9b0721\', \'source\': \'common_runtime.cs-capability\', \'session_id\': \'a5beda79-6c6a-4baf-8bc0-f0fb8a90c8f1\', \'version\': \'0.0.1.20220418.5\', \'commit\': \'87a652d\', \'branch\': \'origin/87a652dc63411a4c682ac7b17bcfa26c9fbb0e4e\', \'custom_dimensions\': {\'artifact_type\': \'installed\', \'ci_number\': \'20220418.5\', \'ci_name\': \'CommonRuntime-prod-build\', \'build_time\': \'2022-04-19 05:16:44.989920\', \'subscription_id\': \'a8b508b6-da16-4c45-84f5-cac5c9f57513\', \'resource_group\': \'azure-mlops\', \'workspace_name\': \'prod-dev-ml-ws\', \'workspace_location\': \'eastus\', \'experiment_name\': \'greet-run\', \'node_rank\': \'0\', \'node_id\': \'a5beda79-6c6a-4baf-8bc0-f0fb8a90c8f1\', \'run_id\': \'greet-run_1650543902_1f9b0721\', \'correlation_id\': \'greet-run_1650543902_1f9b0721\', \'source\': \'common_runtime.cs-capability\', \'session_id\': \'a5beda79-6c6a-4baf-8bc0-f0fb8a90c8f1\', \'version\': \'0.0.1.20220418.5\', \'commit\': \'87a652d\', \'branch\': \'origin/87a652dc63411a4c682ac7b17bcfa26c9fbb0e4e\'}}\nINFO 2022-04-21 12:25:11,941 tracer.py:30 [1] - Setting up tracer {\'component_name\': \'cs-capability\', \'telemetry_config\': \'{"collector": {"exporter": {"appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e"}}}, "logger": {"appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e", "level": "info", "enabled": true}, "file": {"extension": "log", "level": "info", "enabled": true}}}\', \'subscription_id\': \'a8b508b6-da16-4c45-84f5-cac5c9f57513\', \'resource_group\': \'azure-mlops\', \'workspace_name\': \'prod-dev-ml-ws\', \'workspace_location\': \'eastus\', \'experiment_name\': \'greet-run\', \'node_rank\': \'0\', \'node_id\': \'a5beda79-6c6a-4baf-8bc0-f0fb8a90c8f1\', \'run_id\': \'greet-run_1650543902_1f9b0721\', \'correlation_id\': \'greet-run_1650543902_1f9b0721\', \'source\': \'common_runtime.cs-capability\', \'session_id\': \'a5beda79-6c6a-4baf-8bc0-f0fb8a90c8f1\', \'version\': \'0.0.1.20220418.5\', \'commit\': \'87a652d\', \'branch\': \'origin/87a652dc63411a4c682ac7b17bcfa26c9fbb0e4e\', \'custom_dimensions\': {\'component_name\': \'cs-capability\', \'telemetry_config\': \'{"collector": {"exporter": {"appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e"}}}, "logger": {"appinsights": {"instrumentation_key": "f28ce674-24be-48c0-8921-296f59db039e", "level": "info", "enabled": true}, "file": {"extension": "log", "level": "info", "enabled": true}}}\', \'subscription_id\': \'a8b508b6-da16-4c45-84f5-cac5c9f57513\', \'resource_group\': \'azure-mlops\', \'workspace_name\': \'prod-dev-ml-ws\', \'workspace_location\': \'eastus\', \'experiment_name\': \'greet-run\', \'node_rank\': \'0\', \'node_id\': \'a5beda79-6c6a-4baf-8bc0-f0fb8a90c8f1\', \'run_id\': \'greet-run_1650543902_1f9b0721\', \'correlation_id\': \'greet-run_1650543902_1f9b0721\', \'source\': \'common_runtime.cs-capability\', \'session_id\': \'a5beda79-6c6a-4baf-8bc0-f0fb8a90c8f1\', \'version\': \'0.0.1.20220418.5\', \'commit\': \'87a652d\', \'branch\': \'origin/87a652dc63411a4c682ac7b17bcfa26c9fbb0e4e\'}}\nINFO 2022-04-21 12:25:11,941 tracer.py:55 [1] - Setting up appinsights exporter {\'subscription_id\': \'a8b508b6-da16-4c45-84f5-cac5c9f57513\', \'resource_group\': \'azure-mlops\', \'workspace_name\': \'prod-dev-ml-ws\', \'workspace_l ...
#   'system_logs/hosttools_capability/hosttools-capability.log': '2022-04-21T12:25:11.251773Z  INFO telemetry: job_telemetry_init artifact_type=installed branch=origin/87a652dc63411a4c682ac7b17bcfa26c9fbb0e4e ci_number=20220418.5 ci_name=CommonRuntime-prod-build build_time=2022-04-19 05:16:43.089333\n2022-04-21T12:25:11.254040Z  INFO hosttools-capability::do_main: hosttools_capability: Hosttools cap config ht_cap_config={"dirs":[{"relative_path":"user_logs","environment_name":"AZUREML_CR_HT_CAP_user_logs_PATH","streamable":true},{"relative_path":"azureml-logs","environment_name":"AZUREML_CR_HT_CAP_azureml_logs_PATH","streamable":true},{"relative_path":"outputs","environment_name":"AZUREML_CR_HT_CAP_outputs_PATH","streamable":false},{"relative_path":"logs","environment_name":"AZUREML_CR_HT_CAP_logs_PATH","streamable":true}],"metrics":{"enabled":true,"polling_interval_sec":30,"send_to_history_interval_sec":60},"use_block_blob_in_blob_streamer":true,"log_filtering_policy":null}\n2022-04-21T12:25:11.254668Z  INFO hosttools-capability::do_main:hosttools-capability.parse_config: hosttools_capability::config_parser: appinsights instrumentation key is set in telemetry config\n2022-04-21T12:25:11.254745Z  INFO hosttools-capability::do_main:hosttools-capability.parse_config:hosttools-capability.add_cert_env_vars_from_file{path="/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/cap/hosttools-capability/wd/cert_info.txt"}: hosttools_capability::config_parser: Cert envs from cert_file was successful\n2022-04-21T12:25:11.254761Z  INFO hosttools-capability::do_main:hosttools-capability.parse_config:hosttools-capability.add_cert_env_vars_from_file{path="/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/cap/hosttools-capability/wd/cert_info.txt"}: hosttools_capability::config_parser: close time.busy=56.2µs time.idle=7.90µs\n2022-04-21T12:25:11.255013Z  INFO hosttools-capability::do_main:hosttools-capability.parse_config: hosttools_capability::config_parser: close time.busy=551µs time.idle=5.30µs\n2022-04-21T12:25:11.259332Z  INFO hosttools-capability::do_main:hosttools-capability.start_nodestatsagent: hosttools_capability::hosttools: child spawned child=Child { child: Child(ChildDropGuard { inner: Child { pid: 14 }, kill_on_drop: false }), stdin: None, stdout: Some(ChildStdout { inner: PollEvented { io: Some(Pipe { fd: File { fd: 16, path: "pipe:[80077]", read: true, write: false } }) } }), stderr: Some(ChildStderr { inner: PollEvented { io: Some(Pipe { fd: File { fd: 18, path: "pipe:[80078]", read: true, write: false } }) } }) }\n2022-04-21T12:25:11.259731Z  INFO hosttools-capability::do_main:hosttools-capability.start_nodestatsagent: hosttools_capability::hosttools: close time.busy=3.16ms time.idle=4.40µs\n2022-04-21T12:25:11.260304Z  INFO hosttools-capability::do_main:hosttools-capability.start_hosttools{task="outputManager"}: hosttools_capability::hosttools: child spawned child=Child { child: Child(ChildDropGuard { inner: Child { pid: 18 }, kill_on_drop: false }), stdin: None, stdout: Some(ChildStdout { inner: PollEvented { io: Some(Pipe { fd: File { fd: 17, path: "pipe:[80081]", read: true, write: false } }) } }), stderr: Some(ChildStderr { inner: PollEvented { io: Some(Pipe { fd: File { fd: 20, path: "pipe:[80082]", read: true, write: false } }) } }) }\n2022-04-21T12:25:11.260701Z  INFO hosttools-capability::do_main:hosttools-capability.start_hosttools{task="outputManager"}: hosttools_capability::hosttools: close time.busy=899µs time.idle=4.70µs\n2022-04-21T12:25:11.260819Z  INFO hosttools-capability::do_main: hosttools_capability: Starting gRPC server at server_addr=/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/hosttools-capability:0\n2022-04-21T12:25:11.260856Z  INFO hosttools-capability::do_main: hosttools_capability::service: serving capability service at address=/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/hosttools-capability:0\n2022-04-21T12:25:11.260948Z  INFO hosttools-capability::do_main:serve: grpc_utils ...
#   'system_logs/lifecycler/execution-wrapper.log': '2022-04-21T12:25:12.071564Z  INFO telemetry: job_telemetry_init artifact_type=installed branch=origin/87a652dc63411a4c682ac7b17bcfa26c9fbb0e4e ci_number=20220418.5 ci_name=CommonRuntime-prod-build build_time=2022-04-19 05:16:52.493351\n2022-04-21T12:25:12.073294Z  INFO run_execution_wrapper: execution_wrapper: Successfully dumped bootstrapping environment to file\n2022-04-21T12:25:12.073340Z  INFO run_execution_wrapper:execution-wrapper::run_service{distributed_config=None path_mapping_kind=None enable_std_log_streaming=false}: execution_wrapper::service: serving execution service at executor_address=/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/executor:0\n2022-04-21T12:25:12.073467Z  INFO run_execution_wrapper:execution-wrapper::run_service{distributed_config=None path_mapping_kind=None enable_std_log_streaming=false}:serve: grpc_utils::endpoint::serve: serving gRPC service endpoint=Uds("/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/executor:0") retry=ExponentialBackoffRetry { retry_delay_secs: 2, delay_factor: 1000, num_retries: 3 }\n2022-04-21T12:25:17.285289Z  INFO ExecutionServicer::run: grpc_utils::server: Got grpc request name="run" remote_addr=None\n2022-04-21T12:25:17.285363Z  INFO ExecutionServicer::run:ExecutionServicer::spawn_execution{finalization=None}: execution_wrapper::service: spawn_execution request id="05ccbd67-4abb-4d75-a372-7624631314df"\n2022-04-21T12:25:17.285532Z  INFO ExecutionServicer::run:ExecutionServicer::spawn_execution{finalization=None}: execution_wrapper::infiniband_utils: Is InfiniBand device present: false infiniband_device_path="/dev/infiniband/uverbs0"\n2022-04-21T12:25:17.285563Z  INFO ExecutionServicer::run:ExecutionServicer::spawn_execution{finalization=None}: execution_wrapper::service: Spawning execution\n2022-04-21T12:25:17.286279Z  INFO ExecutionServicer::run:ExecutionServicer::spawn_execution{finalization=None}:Execution::parse_commands: execution_wrapper::execution: close time.busy=155µs time.idle=8.10µs\n2022-04-21T12:25:17.286750Z  INFO ExecutionServicer::run:ExecutionServicer::spawn_execution{finalization=None}:Execution::spawn: execution_wrapper::execution: Spawning target process\n2022-04-21T12:25:17.288074Z  INFO ExecutionServicer::run:ExecutionServicer::spawn_execution{finalization=None}:Execution::spawn: execution_wrapper::execution: execution process spawned pid=17\n2022-04-21T12:25:17.288696Z  INFO execution_wrapper::execution: start waiting for processes execution to complete num_processes=1\n2022-04-21T12:25:17.288826Z  INFO Execution::wait_for_completion{parent_span=Span { name: "Execution::spawn", level: Level(Info), target: "execution_wrapper::execution", id: Id(4503874505277443), module_path: "execution_wrapper::execution", line: 105, file: "executor/execution-wrapper/src/execution/mod.rs" } process_manager=Mutex { data: ProcessManager { dangling_processes: [], user_process_groups: [17] } }}: execution_wrapper::execution::process_manager: ProcessManagerExecution state changing from PendingExecution to PendingExecution\n2022-04-21T12:25:18.535298Z  INFO Execution::send_stdout_with_prefix{enable_std_log_streaming=false}: execution_wrapper::execution: close time.busy=63.0µs time.idle=1.25s\n2022-04-21T12:25:18.535311Z  INFO Execution::send_stderr_with_prefix{enable_std_log_streaming=false}: execution_wrapper::execution: close time.busy=28.6µs time.idle=1.25s\n2022-04-21T12:25:18.535358Z  INFO Execution::write_logs_to_file: execution_wrapper::execution: close time.busy=43.3µs time.idle=1.25s\n2022-04-21T12:25:18.535478Z  INFO Execution::wait_for_completion{parent_span=Span { name: "Execution::spawn", level: Level(Info), target: "execution_wrapper::execution", id: Id(4503874505277443), module_path: "execution_wrapper::execution", line: 105, file: "executor/execution-wrapper/src/execution/mod.rs" } process_manager=Mutex { data: ProcessManager { dangling_processes: [], user_process_groups: [17] } }} ...
#   'system_logs/lifecycler/lifecycler.log': '2022-04-21T12:25:11.255044Z  INFO telemetry: job_telemetry_init artifact_type=installed branch=origin/87a652dc63411a4c682ac7b17bcfa26c9fbb0e4e ci_number=20220418.5 ci_name=CommonRuntime-prod-build build_time=2022-04-19 05:17:03.986654\n2022-04-21T12:25:11.255261Z  INFO load_config_from_env: lifecycler::config: Resolved grpc addresses lifecycler_address=/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/lifecycler:0 executor_address=/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/executor:0\n2022-04-21T12:25:11.255404Z  INFO load_config_from_env:load_capability_addresses_from_env: lifecycler::config: loaded capability address for CS_CAPABILITY cap_name=CS_CAPABILITY address=/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/cs-capability:0\n2022-04-21T12:25:11.255428Z  INFO load_config_from_env:load_capability_addresses_from_env: lifecycler::config: loaded capability address for HOSTTOOLS_CAPABILITY cap_name=HOSTTOOLS_CAPABILITY address=/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/hosttools-capability:0\n2022-04-21T12:25:11.255500Z  INFO load_config_from_env:load_capability_addresses_from_env: lifecycler::config: close time.busy=215µs time.idle=5.80µs\n2022-04-21T12:25:11.255664Z  INFO load_config_from_env: lifecycler::config: close time.busy=553µs time.idle=11.0µs\n2022-04-21T12:25:11.255697Z  INFO run_lifecycler:run_service_and_step_through_lifecycle: lifecycler::lifecycle: distributed config is not specified, skip setting up distributed barrier\n2022-04-21T12:25:11.255838Z  INFO run_lifecycler:run_service_and_step_through_lifecycle:step_through_lifecycle:connect_capabilities:connect: grpc_utils::endpoint::connect: Connecting to gRPC service endpoint=Uds("/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/cs-capability:0") retry=FixedIntervalRetry { attempt_timeout_millis: 50, retry_delay_millis: 10, max_duration: 86400s }\n2022-04-21T12:25:11.256290Z  INFO Lifecycler::run_service{distributed_state_sender=None}: lifecycler::service: serving lifecycle service address=/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/lifecycler:0\n2022-04-21T12:25:11.256439Z  INFO Lifecycler::run_service{distributed_state_sender=None}:serve_more: grpc_utils::endpoint::serve: serving gRPC service endpoint=Uds("/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/lifecycler:0") retry=ExponentialBackoffRetry { retry_delay_secs: 2, delay_factor: 1000, num_retries: 3 }\n2022-04-21T12:25:11.983075Z  INFO run_lifecycler:run_service_and_step_through_lifecycle:step_through_lifecycle:connect_capabilities:connect: grpc_utils::endpoint::connect: Successfully connected to gRPC service endpoint=Uds("/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/cs-capability:0")\n2022-04-21T12:25:11.983137Z  INFO run_lifecycler:run_service_and_step_through_lifecycle:step_through_lifecycle:connect_capabilities:connect: grpc_utils::endpoint::connect: close time.busy=12.2ms time.idle=715ms\n2022-04-21T12:25:11.986732Z  INFO run_lifecycler:run_service_and_step_through_lifecycle:step_through_lifecycle:connect_capabilities:connect: grpc_utils::endpoint::connect: Connecting to gRPC service endpoint=Uds("/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/cs-capability:0") retry=FixedIntervalRetry { attempt_timeout_millis: 50, retry_delay_millis: 10, max_duration: 86400s }\n2022-04-21T12:25:11.986940Z  INFO run_lifecycler:run_service_and_step_through_lifecycle:step_through_lifecycle:connect_capabilities:connect: grpc_utils::endpoint::connect: Successfully connected to gRPC service endpoint=Uds("/mnt/azureml/cr/j/2354d607943846cf98578b2122841843/.grpc/cs-capability:0")\n2022-04-21T12:25:11.986968Z  INFO run_lifecycler:run_service_and_step_through_lifecycle:step_through_lifecycle:connect_capabilities:connect: grpc_utils::endpoint::connect: close time.busy=237µs time.idle=6.30µs\n2022-04-21T12:25:11.987084Z  INFO run_lifecycler:run_service_and_step_through_lifecycle:step_throug ...
#   'system_logs/lifecycler/vm-bootstrapper.log': '2022-04-21T12:25:10.657877Z  INFO telemetry: job_telemetry_init artifact_type=binimage branch=origin/87a652dc63411a4c682ac7b17bcfa26c9fbb0e4e ci_number=20220418.5 ci_name=CommonRuntime-prod-build build_time=2022-04-19 05:27:24.318413\n2022-04-21T12:25:10.658102Z  INFO vm_bootstrapper: The amlcompute is Dedicated, skip poll preemption signal\n2022-04-21T12:25:10.667249Z  INFO xds_client::build_xds_client: vm_bootstrapper::batchai::service_client: close time.busy=9.12ms time.idle=3.70µs\n2022-04-21T12:25:10.667309Z  INFO vm_bootstrapper::batchai::service_client: Build XDS client successfully\n2022-04-21T12:25:10.667402Z  INFO xds_client::post_job_status_to_xds{job_status=Running job_exit_code=0 job_err=None}: vm_bootstrapper::batchai::service_client: Post job status to XDS job_status=Running\n2022-04-21T12:25:10.667646Z  INFO update_runtime_type:vienna_client::run_history::update_runs{service_endpoint="https://eastus.api.azureml.ms" run_id=RunId { subscription_id: "a8b508b6-da16-4c45-84f5-cac5c9f57513", resource_group_name: "azure-mlops", workspace_name: "prod-dev-ml-ws", experiment_name: "greet-run", run_id: "greet-run_1650543902_1f9b0721" } create_run=Some(CreateRun { run_id: None, parent_run_id: None, experiment_id: None, status: None, start_time_utc: None, end_time_utc: None, options: None, is_virtual: None, tensorboard_paths: None, display_name: None, name: None, data_container_id: None, description: None, hidden: None, run_type: None, run_type_v2: Some(RunTypeV2 { orchestrator: None, traits: Some(["CommonRuntime"]) }), properties: None, parameters: None, action_uris: None, script_name: None, target: None, unique_child_run_compute_targets: None, tags: None, settings: None, endpoint_settings: None, services: None, input_datasets: None, output_datasets: None, run_definition: None, primary_metric_name: None, created_from: None, cancel_uri: None, complete_uri: None, diagnostics_uri: None, compute_request: None, retain_for_lifetime_of_workspace: None, queueing_info: None, active_child_run_id: None })}: vienna_client::run_history: Calling service service_endpoint="https://eastus.api.azureml.ms"\n2022-04-21T12:25:10.669780Z  INFO vm-bootstrapper::do_main: vm_bootstrapper: vm-bootstrapper::start registry_override=Some(CapabilitiesRegistryConfig { registry: Some(RegistryConfig { url: "viennaglobal.azurecr.io", identity_token: None, username: Some("vienna-global-reader"), password: Some("[REDACTED]") }), repo_prefix: None, regional_tag_prefix: true }) resource_constraints=Some(ResourceConstraints { cpu_shares: Some(6144), reserved_mem_mb: Some(650), sys_cpu_shares: Some(1024), sys_reserved_mem_mb: Some(500) }) disk_thresholds=Some(DiskThresholds { disk_free_before_job_mb: Some(1500), disk_free_after_job_mb: Some(5000) }) docker_retries_override=None termination_signal_receiver=Mutex { data: broadcast::Receiver } batchai_config=BatchAIConfig { cluster_name: "akt-cluster", node_id: "tvmps_46864454dd0112a5b8e8c76d4244eb1077196e4690e4d00741b33ac0424fb7be_d", all_node_ips: None, rank0_ip: None, task_user: Some("_azbatch"), identity_client_id: None, xds_service_config: Some(XdsServiceConfig { service_name: "XDS", endpoint: "https://eastus.cert.api.azureml.ms/xdsbatchai", privatelink_endpoint: None, api_version: "2018-02-01" }), parallel_task_index: None, is_cluster_under_vnet: false, is_private_link: false, vm_priority: Dedicated, job_attempt_count: 1, gpu_count: 0, vm_size: Some("STANDARD_DS11_V2"), node_shared_dir: Some("/mnt"), node_root_dir: Some("/mnt/batch/tasks"), azureml_run_token: Some("[REDACTED]") } distributed_config=None job_id="2354d607943846cf98578b2122841843" job_volume=Volume { name: "2354d607943846cf98578b2122841843", host_path: Some("/mnt/azureml/cr/j/2354d607943846cf98578b2122841843"), empty_dir: None, remove_from_host_during_cleanup: true }\n2022-04-21T12:25:10.669966Z  INFO vm-bootstrapper::do_main: vm_bootstrapper::command::identity_responder: Selected port for Identit ...
#  'submittedBy': 'Aniket Thani'}

# %% [markdown]
# ### Training the diabetes model on a compute cluster

# %%
from azureml.core import Dataset
from azureml.core import Workspace
ws=Workspace.from_config()

# %%
from azureml.core import Datastore

# %%
dstore=ws.get_default_datastore()

# %%
dstore.upload_files(files=["data/diabetes.csv"],target_path="/diabetes_data",overwrite=True,show_progress=True)
# Out:
# Uploading an estimated of 1 files
# Uploading data/diabetes.csv
# Uploaded data/diabetes.csv, 1 files out of an estimated total of 1
# Uploaded 1 files
# $AZUREML_DATAREFERENCE_c4746e11a0e0484c82c8a0d55562d047

# %%
file_paths=[
    (dstore,"/diabetes_data"),
]

dataset=Dataset.Tabular.from_delimited_files(path=file_paths)

# %%
dataset.register(ws,name="diabetes",description="diabetes data")
# Out:
# {
#   "source": [
#     "('workspaceblobstore', '/diabetes_data')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns",
#     "SetColumnTypes"
#   ],
#   "registration": {
#     "id": "5f539135-26c4-4cf8-bda9-27822f3b322a",
#     "name": "diabetes",
#     "version": 1,
#     "description": "diabetes data",
#     "workspace": "Workspace.create(name='prod-dev-ml-ws', subscription_id='a8b508b6-da16-4c45-84f5-cac5c9f57513', resource_group='azure-mlops')"
#   }
# }

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.22.1

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies 
import sklearn

diabetes_env = Environment(name="diabetes-training-env")
diabetes_env.python.conda_dependencies = CondaDependencies.create(conda_packages=["scikit-learn"],pip_packages=["azureml-dataprep[pandas]","joblib","azureml-core","numpy","pandas"])

# %%
from azureml.core import Workspace, Experiment
from azureml.core import ScriptRunConfig

ws = Workspace.from_config()
target = ws.compute_targets['akt-cluster']

script = ScriptRunConfig(
    source_directory='diabetes-training',
    script='training.py',
    environment=diabetes_env,
    compute_target=target,

)

exp = Experiment(ws, 'diabetes_cluster_execution')
run = exp.submit(script)
run.wait_for_completion(show_output=True)
# Out:
# RunId: diabetes_cluster_execution_1650546838_8d8c1f30
# Web View: https://ml.azure.com/runs/diabetes_cluster_execution_1650546838_8d8c1f30?wsid=/subscriptions/a8b508b6-da16-4c45-84f5-cac5c9f57513/resourcegroups/azure-mlops/workspaces/prod-dev-ml-ws&tid=e648628f-f65c-40cc-8a28-c601daf26a89
#
# Execution Summary
# =================
# RunId: diabetes_cluster_execution_1650546838_8d8c1f30
# Web View: https://ml.azure.com/runs/diabetes_cluster_execution_1650546838_8d8c1f30?wsid=/subscriptions/a8b508b6-da16-4c45-84f5-cac5c9f57513/resourcegroups/azure-mlops/workspaces/prod-dev-ml-ws&tid=e648628f-f65c-40cc-8a28-c601daf26a89
# {'runId': 'diabetes_cluster_execution_1650546838_8d8c1f30',
#  'target': 'akt-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2022-04-21T13:14:08.723412Z',
#  'endTimeUtc': '2022-04-21T13:14:28.602853Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlctrain',
#   'ContentSnapshotId': '8dab90e4-e2b7-4e12-a8e8-729178731ee8',
#   'azureml.git.repository_uri': 'https://github.com/Aniketthani/Azure-Remote-Script-Execution-on-Clusters.git',
#   'mlflow.source.git.repoURL': 'https://github.com/Aniketthani/Azure-Remote-Script-Execution-on-Clusters.git',
#   'azureml.git.branch': 'main',
#   'mlflow.source.git.branch': 'main',
#   'azureml.git.commit': '6a9e584a6a9f57f3a693b331ee5df39f4387bfa2',
#   'mlflow.source.git.commit': '6a9e584a6a9f57f3a693b331ee5df39f4387bfa2',
#   'azureml.git.dirty': 'True',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': '5f539135-26c4-4cf8-bda9-27822f3b322a'}, 'consumptionDetails': {'type': 'Reference'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'training.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'akt-cluster',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'diabetes-training-env',
#    'version': 'Autosave_2022-04-21T12:26:39Z_e36ad9dc',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'name': 'project_environment',
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-dataprep[pandas]',
#         'joblib',
#         'azureml-core~=1.40.0',
#         'numpy',
#         'pandas']},
#       'scikit-learn'],
#      'channels': ['anaconda', 'conda-forge']},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220314.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'sshPublicKeys': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'logs/azureml/dataprep/backgroundProcess.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_cluster_execution_1650546838_8d8c1f30/logs/azureml/dataprep/backgroundProcess.log?sv=2019-07-07&sr=b&sig=RcdeiV1%2FLy8DTzlaBGOpJptFtlk%2BrzQR4mCnuQkhA6k%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T13%3A04%3A25Z&se=2022-04-21T21%3A14%3A25Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_cluster_execution_1650546838_8d8c1f30/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-07-07&sr=b&sig=kWvFhmPNzluwW%2BPqyfviMXzF%2F89gk4tm9PP25qn7lQU%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T13%3A04%3A25Z&se=2022-04-21T21%3A14%3A25Z&sp=r',
#   'logs/azureml/dataprep/rslex.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_cluster_execution_1650546838_8d8c1f30/logs/azureml/dataprep/rslex.log?sv=2019-07-07&sr=b&sig=0QTUAwuYw4kg2s6zIwGv1y7fj1ELBETpV73FT%2Fp2GNY%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T13%3A04%3A25Z&se=2022-04-21T21%3A14%3A25Z&sp=r',
#   'logs/azureml/dataprep/rslex.log.2022-04-21-13': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_cluster_execution_1650546838_8d8c1f30/logs/azureml/dataprep/rslex.log.2022-04-21-13?sv=2019-07-07&sr=b&sig=C07tRTEvYdfZGNr1oCdPWILVjNBJwsqhih%2BQSnTzwc8%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T13%3A04%3A25Z&se=2022-04-21T21%3A14%3A25Z&sp=r',
#   'user_logs/std_log.txt': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_cluster_execution_1650546838_8d8c1f30/user_logs/std_log.txt?sv=2019-07-07&sr=b&sig=6jdJvaNfa0VV06h4FbwxsJapB9ZTSE0mfbPVZVxPvD0%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T13%3A04%3A31Z&se=2022-04-21T21%3A14%3A31Z&sp=r',
#   'system_logs/cs_capability/cs-capability.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_cluster_execution_1650546838_8d8c1f30/system_logs/cs_capability/cs-capability.log?sv=2019-07-07&sr=b&sig=MlOWlBTh1POg5eN0kLOMuRMyGDlno1wX091zVD5kJuE%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T13%3A04%3A31Z&se=2022-04-21T21%3A14%3A31Z&sp=r',
#   'system_logs/hosttools_capability/hosttools-capability.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_cluster_execution_1650546838_8d8c1f30/system_logs/hosttools_capability/hosttools-capability.log?sv=2019-07-07&sr=b&sig=dZJMna4ZLAFIZNbj1b%2ButTzTU5dX8QJE6RmmHlFnhxQ%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T13%3A04%3A31Z&se=2022-04-21T21%3A14%3A31Z&sp=r',
#   'system_logs/lifecycler/execution-wrapper.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_cluster_execution_1650546838_8d8c1f30/system_logs/lifecycler/execution-wrapper.log?sv=2019-07-07&sr=b&sig=WQBdBKKxDDiUU4vhwt2GnzUlGczRvwTCq0w%2FFLTrEcc%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T13%3A04%3A31Z&se=2022-04-21T21%3A14%3A31Z&sp=r',
#   'system_logs/lifecycler/lifecycler.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_cluster_execution_1650546838_8d8c1f30/system_logs/lifecycler/lifecycler.log?sv=2019-07-07&sr=b&sig=BT02Rv%2FP2tiIiKVl%2BH12Uc6YDK8%2BNZPzWHUj4%2BonvtU%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T13%3A04%3A31Z&se=2022-04-21T21%3A14%3A31Z&sp=r',
#   'system_logs/lifecycler/vm-bootstrapper.log': 'https://proddevmlws2831478418.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_cluster_execution_1650546838_8d8c1f30/system_logs/lifecycler/vm-bootstrapper.log?sv=2019-07-07&sr=b&sig=FY6D1Boa48jhxxquoL7cGPJzgDp3dgKdlhMJu%2BU0wng%3D&skoid=5527afab-2da3-4a76-8012-26fde488231e&sktid=e648628f-f65c-40cc-8a28-c601daf26a89&skt=2022-04-21T12%3A09%3A08Z&ske=2022-04-22T20%3A19%3A08Z&sks=b&skv=2019-07-07&st=2022-04-21T13%3A04%3A31Z&se=2022-04-21T21%3A14%3A31Z&sp=r'},
#  'submittedBy': 'Aniket Thani'}
